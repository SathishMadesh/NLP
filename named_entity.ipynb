# %%
sentence = "The Eiffel Tower was built from 1887 to 1889 by French engineer Gustave Eiffel, whose company specialized in building metal frameworks and structures."

# %%
import nltk
words = nltk.word_tokenize(sentence)

# %%
nltk.download('averaged_perceptron_tagger_eng')

tag_element = nltk.pos_tag(words)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!

# %%
# %pip install svglib
# Out:
# Collecting svglib
#   Downloading svglib-1.6.0-py3-none-any.whl.metadata (11 kB)
# Collecting cssselect2>=0.2.0 (from svglib)
#   Downloading cssselect2-0.8.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: lxml>=6.0.0 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from svglib) (6.0.2)
# Collecting reportlab>=4.4.3 (from svglib)
#   Downloading reportlab-4.4.7-py3-none-any.whl.metadata (1.7 kB)
# Collecting rlpycairo>=0.4.0 (from svglib)
#   Downloading rlpycairo-0.4.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: tinycss2>=0.6.0 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from svglib) (1.4.0)
# Requirement already satisfied: webencodings in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from cssselect2>=0.2.0->svglib) (0.5.1)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from reportlab>=4.4.3->svglib) (11.3.0)
# Requirement already satisfied: charset-normalizer in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from reportlab>=4.4.3->svglib) (3.4.2)
# Collecting pycairo>=1.20.0 (from rlpycairo>=0.4.0->svglib)
#   Downloading pycairo-1.29.0-cp312-cp312-win_amd64.whl.metadata (2.3 kB)
# Collecting freetype-py>=2.3 (from rlpycairo>=0.4.0->svglib)
#   Downloading freetype_py-2.5.1-py3-none-win_amd64.whl.metadata (6.5 kB)
# Downloading svglib-1.6.0-py3-none-any.whl (39 kB)
# Downloading cssselect2-0.8.0-py3-none-any.whl (15 kB)
# Downloading reportlab-4.4.7-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 21.7 MB/s  0:00:00
# Downloading rlpycairo-0.4.0-py3-none-any.whl (7.6 kB)
# Downloading freetype_py-2.5.1-py3-none-win_amd64.whl (814 kB)
#    ---------------------------------------- 0.0/814.6 kB ? eta -:--:--
#    ---------------------------------------- 814.6/814.6 kB 17.8 MB/s  0:00:00
# Downloading pycairo-1.29.0-cp312-cp312-win_amd64.whl (845 kB)
#    ---------------------------------------- 0.0/845.4 kB ? eta -:--:--
#    ---------------------------------------- 845.4/845.4 kB 36.5 MB/s  0:00:00
# Installing collected packages: reportlab, pycairo, freetype-py, rlpycairo, cssselect2, svglib
#
#    ---------------------------------------- 0/6 [reportlab]
#    ---------------------------------------- 0/6 [reportlab]
#    ---------------------------------------- 0/6 [reportlab]
#    ---------------------------------------- 0/6 [reportlab]
#    ---------------------------------------- 0/6 [reportlab]
#    ---------------------------------------- 0/6 [reportlab]
#    ---------------------------------------- 0/6 [reportlab]
#    ---------------------------------------- 0/6 [reportlab]
#    ---------------------------------------- 0/6 [reportlab]
#    ---------------------------------------- 0/6 [reportlab]
#    ---------------------------------------- 0/6 [reportlab]
#    ---------------------------------------- 0/6 [reportlab]
#    ---------------------------------------- 0/6 [reportlab]
#    ---------------------------------------- 0/6 [reportlab]
#    ---------------------------------------- 0/6 [reportlab]
#    ---------------------------------------- 0/6 [reportlab]
#    ------ --------------------------------- 1/6 [pycairo]
#    ------------- -------------------------- 2/6 [freetype-py]
#    ------------- -------------------------- 2/6 [freetype-py]
#    ------------- -------------------------- 2/6 [freetype-py]
#    -------------------------- ------------- 4/6 [cssselect2]
#    --------------------------------- ------ 5/6 [svglib]
#    ---------------------------------------- 6/6 [svglib]
#
# Successfully installed cssselect2-0.8.0 freetype-py-2.5.1 pycairo-1.29.0 reportlab-4.4.7 rlpycairo-0.4.0 svglib-1.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install svgling
# Out:
# Collecting svgling
#   Downloading svgling-0.5.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting svgwrite (from svgling)
#   Downloading svgwrite-1.4.3-py3-none-any.whl.metadata (8.8 kB)
# Downloading svgling-0.5.0-py3-none-any.whl (31 kB)
# Downloading svgwrite-1.4.3-py3-none-any.whl (67 kB)
# Installing collected packages: svgwrite, svgling
#
#    ---------------------------------------- 0/2 [svgwrite]
#    ---------------------------------------- 0/2 [svgwrite]
#    ---------------------------------------- 0/2 [svgwrite]
#    -------------------- ------------------- 1/2 [svgling]
#    ---------------------------------------- 2/2 [svgling]
#
# Successfully installed svgling-0.5.0 svgwrite-1.4.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

from IPython.display import display

nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
nltk.download('averaged_perceptron_tagger_eng')

display(nltk.ne_chunk(tag_element))
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\Acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# Tree('S', [('The', 'DT'), Tree('ORGANIZATION', [('Eiffel', 'NNP'), ('Tower', 'NNP')]), ('was', 'VBD'), ('built', 'VBN'), ('from', 'IN'), ('1887', 'CD'), ('to', 'TO'), ('1889', 'CD'), ('by', 'IN'), Tree('GPE', [('French', 'JJ')]), ('engineer', 'NN'), Tree('PERSON', [('Gustave', 'NNP'), ('Eiffel', 'NNP')]), (',', ','), ('whose', 'WP$'), ('company', 'NN'), ('specialized', 'VBD'), ('in', 'IN'), ('building', 'NN'), ('metal', 'NN'), ('frameworks', 'NNS'), ('and', 'CC'), ('structures', 'NNS'), ('.', '.')])
